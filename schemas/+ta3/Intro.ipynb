# %% [markdown]
# # TA3 Segmentation Pipeline
#
# This is the pipeline for EM segmentation data.
#
# To connect, obtain your credentials on `datajoint.ninai.org`.

# %%
import datajoint as dj
dj.config['database.user'] = 'dimitri'    #  change to your username
dj.config['database.host'] = 'at-database'

# %% [markdown]
# Connect to schemas `microns_ta3` and `microns_nda`

# %%
import ta3
nda = dj.create_virtual_module('nda', 'microns_nda')

# %%
dj.ERD(ta3) -1

# %%
ta3.Synapse()
# Out:
# *segmentation  *synapse_id    presyn       postsyn      synapse_x     synapse_y     synapse_z
# +------------+ +------------+ +----------+ +----------+ +-----------+ +-----------+ +-----------+
# 1              1130746        61948443     61834293     64583.0       24964.0       948.0
# 1              1130747        95602281     25571519     54843.0       32489.0       331.0
# 1              1130748        1464153      1555184      30347.0       8181.0        92.0
# 1              1130749        27347377     27350423     63991.0       14735.0       990.0
# 1              1130750        28055590     27659161     17133.0       19422.0       847.0
# 1              1130751        60473842     26573393     39673.0       28820.0       659.0
# 1              1130752        36196304     28578313     25781.0       18178.0       793.0
#    ...
